# %%
import os
from openai import OpenAI
import pandas as pd
import tqdm

client = OpenAI(api_key="")

# %%
def prompt_for_question_rephrasing(question):
   prompt = f"""You are a professional question rephraser specializing in generating lexically diverse variations. Your task is to produce **6 maximally divergent** rephrasings of the input question.

### CORE INSTRUCTIONS FOR MINIMAL OVERLAP

1.  **Preserve Intent:** Each rephrasing must maintain the **exact original meaning, specificity, and scope**. Do not add, remove, or change information.

2.  **Maximize Lexical Distance:**
    * **Goal:** Achieve the lowest possible Jaccard Similarity score (lexical overlap) across all seven questions (Original + 6 Variants).
    * **Prohibited:** Do not use the same content word (nouns, verbs, adjectives, adverbs) more than **once** across all 6 rephrased versions, even if it's a synonym.
    * **Essential Term Handling:** Proper nouns, named entities, dates, and numbers must be preserved, but **must be textually transformed** using alternatives like:
        * **Dates:** Use *ordinal numbers* (e.g., "the 16th of July"), *written-out numbers* (e.g., "July sixteenth"), or *alternative formats* (e.g., "7/16/2025").
        * **Numbers:** Use *written-out words* (e.g., "seven point three"), *fractions* (e.g., "seven and three-tenths"), or *technical abbreviations* (e.g., "M7.3").
        * **Locations:** Use *hypernyms* (e.g., "tri-state area," "the region") or *abbreviations* (e.g., "MI, OH, PA").

3.  **Structural Transformation:**
    * Vary the core grammatical structure for **every** version. Use: passive voice, nominalization (converting a verb to a noun, e.g., "analyze" $\to$ "analysis"), embedded clauses, and rhetorical devices.
    * Change the interrogative word (Who, What, Where, How, Describe, Identify) for **at least four** of the six versions.

4.  **Natural Language Quality:** Each question must be highly fluent, professional, and grammatically impeccable. Avoid any awkward or forced substitutions.

### DIVERSITY GUARANTEE CHECK

Before outputting, confirm that:
1.  All 6 versions use distinct starting words/phrases.
2.  The set of content words (non-stopwords) in version 1 is almost entirely disjoint from the set of content words in version 2, and so on.

### OUTPUT FORMAT
```
1. Rephrase the question using a structural change transformation.
2. Rephrase the question using a different structural change and transformation.
3. Rephrase the question using a different structural change and transformation.    
4. Rephrase the question using a different structural change and transformation.
5. Rephrase the question using a different structural change and transformation.
6. Rephrase the question using a different structural change and transformation.
```

Input Question: "{question}"

Output:
"""

   return prompt

# %%
import json
import os


data = {}
for filename in os.listdir("extracted_QA"):
    if filename.endswith(".json"):
        with open(os.path.join("extracted_QA", filename), "r") as f:
            data= json.load(f)

# %%
len(data)
# Out:
# 3300

# %%
# randomly pick 30 questions from data with seed 42 data is a list of dicts with keys question and answer
import random
random.seed(41)
sampled_questions = random.sample(data, 30)
sampled_questions
# Out:
# [{'category': 'abrupt',
#   'fact': 'More than 1.4 million people have returned or been forced to return to Afghanistan in 2023, including over 1 million from Iran, according to a senior U.N. official.',
#   'question': '"How many people have returned or been forced to return to Afghanistan in 2023, and how many of those were from Iran?"',
#   'answer': '"More than 1.4 million people have returned or been forced to return to Afghanistan in 2023, including over 1 million from Iran, according to a senior U.N. official."'},
#  {'category': 'emergency',
#   'fact': 'Russian troops attacked Kryvyi Rih in Dnipropetrovsk Oblast on July 4, 2025, resulting in eight injuries, including one person in serious condition and three in moderate condition, according to Oleksandr Vilkul, Head of Kryvyi Rih Defence Council.',
#   'question': '"What were the consequences of the Russian troops attacking Kryvyi Rih in Dnipropetrovsk Oblast on July 4, 2025?"',
#   'answer': '"The attack resulted in eight injuries, including one person in serious condition and three in moderate condition, according to Oleksandr Vilkul, Head of Kryvyi Rih Defence Council."'},
#  {'category': 'discovery',
#   'fact': "Ryanair's pricing system defaults all passengers in a booking to the next available fare class, resulting in a solo traveler being quoted £142.69 for a flight from Stansted to Podgorica, while two passengers would be charged £157.69 each for the same flight.\n",
#   'question': '"What is the fare quoted for a solo traveler flying from Stansted to Podgorica with Ryanair\'s pricing system?"',
#   'answer': '"A solo traveler is quoted £142.69 for a flight from Stansted to Podgorica due to Ryanair\'s pricing system, which defaults all passengers in a booking to the next available fare class."'},
#  {'category': 'discovery',
#   'fact': 'The Morgan Hill Police Department discovered a body near Anderson Lake County Park on July 2, 2025, after a drone operator reported a "possible body" at 7:30 PM.',
#   'question': '"What did the Morgan Hill Police Department discover near Anderson Lake County Park on July 2, 2025?"',
#   'answer': '"The Morgan Hill Police Department discovered a body near Anderson Lake County Park on July 2, 2025, after a drone operator reported a \'possible body\' at 7:30 PM."'},
#  {'category': 'abrupt',
#   'fact': 'An emergency alert sent out on July 17, 2025, indicated that the water conditions in Mattoon could remain unsafe for the next three to four days, requiring two consecutive positive test results before the advisory can be lifted.\n',
#   'question': '"What did the emergency alert indicate about the water conditions in Mattoon on July 17, 2025?"',
#   'answer': '"The emergency alert indicated that the water conditions in Mattoon could remain unsafe for the next three to four days, requiring two consecutive positive test results before the advisory can be lifted."'},
#  {'category': 'outbreak',
#   'fact': 'IDPH launched a measles school outbreak prediction dashboard on July 17, 2025, to help local officials assess risk factors and determine necessary actions in response to potential measles exposures in schools.\n',
#   'question': '"What was the purpose of the measles school outbreak prediction dashboard launched by IDPH on July 17, 2025?"',
#   'answer': '"The purpose of the measles school outbreak prediction dashboard launched by IDPH on July 17, 2025, was to help local officials assess risk factors and determine necessary actions in response to potential measles exposures in schools."'},
#  {'category': 'strike',
#   'fact': 'Tracy Youngblom will read from her memoir "Because We Must" at 7 p.m. on July 6, 2025, at Magers & Quinn, 3038 Hennepin Ave. S., Minneapolis, in celebration of winning the University of Massachusetts Press Juniper Prize.',
#   'question': '"What event will Tracy Youngblom participate in at Magers & Quinn in Minneapolis?"',
#   'answer': '"Tracy Youngblom will read from her memoir \'Because We Must\' at Magers & Quinn, 3038 Hennepin Ave. S., Minneapolis, in celebration of winning the University of Massachusetts Press Juniper Prize."'},
#  {'category': 'emergency',
#   'fact': "Hossain's lawyer, Nick Liakas, stated that the Metropolitan Transit Authority attempted to pressure Hossain into settling for $100,000 before the jury's verdict.\n",
#   'question': '"What amount did the Metropolitan Transit Authority attempt to pressure Hossain into settling for before the jury\'s verdict?"',
#   'answer': '"The Metropolitan Transit Authority attempted to pressure Hossain into settling for $100,000 before the jury\'s verdict, according to Hossain\'s lawyer, Nick Liakas."'},
#  {'category': 'outbreak',
#   'fact': 'The current British wholesale electricity market operates under a single geographic price zone, meaning that regardless of location, such as Kinross, Cornwall, or Kent, the underlying market price remains the same.\n',
#   'question': '"What does the current British wholesale electricity market\'s single geographic price zone mean for locations like Kinross, Cornwall, or Kent?"',
#   'answer': '"The current British wholesale electricity market operating under a single geographic price zone means that regardless of location, such as Kinross, Cornwall, or Kent, the underlying market price remains the same."'},
#  {'category': 'emergency',
#   'fact': "A 2021 meta-study by Canada's public health authority identified skull fractures, lacerations, dislocations, brain injuries, contusions, spinal injuries, dental injuries, and burns as the most frequent injuries associated with e-scooter accidents.\n",
#   'question': '"What types of injuries were identified as the most frequent in e-scooter accidents according to a 2021 meta-study by Canada\'s public health authority?"',
#   'answer': '"The most frequent injuries associated with e-scooter accidents, as identified by a 2021 meta-study by Canada\'s public health authority, include skull fractures, lacerations, dislocations, brain injuries, contusions, spinal injuries, dental injuries, and burns."'},
#  {'category': 'abrupt',
#   'fact': "Richard Glossip's attorneys filed court documents on July 16, 2025, claiming that Oklahoma Attorney General Gentner Drummond agreed in 2023 to a plea deal allowing Glossip to plead guilty to accessory after the fact and receive a 45-year sentence for the 1997 killing of Barry Van Treese.",
#   'question': '"What did Richard Glossip\'s attorneys claim regarding a plea deal with Oklahoma Attorney General Gentner Drummond?"',
#   'answer': '"Richard Glossip\'s attorneys claimed that Oklahoma Attorney General Gentner Drummond agreed in 2023 to a plea deal allowing Glossip to plead guilty to accessory after the fact and receive a 45-year sentence for the 1997 killing of Barry Van Treese."'},
#  {'category': 'crash',
#   'fact': 'A vehicle crash on July 3, 2025, caused the eastbound lanes of Sams Circle in Chesapeake, Virginia, to close due to a downed power line, with crews from Dominion Energy on-site for repairs.',
#   'question': '"What caused the closure of the eastbound lanes of Sams Circle in Chesapeake, Virginia, on July 3, 2025?"',
#   'answer': '"The closure of the eastbound lanes of Sams Circle in Chesapeake, Virginia, on July 3, 2025, was caused by a vehicle crash that resulted in a downed power line, with crews from Dominion Energy on-site for repairs."'},
#  {'category': 'crash',
#   'fact': 'Tammy Sandoval, a 55-year-old woman from Mount Morris, was charged on July 3, 2025, with six felonies related to a hit-and-run crash on June 29 that killed three-year-old Khalil Robinson and left his mother Tia Robinson and twin sister Khloe in critical condition.',
#   'question': '"What charges were brought against Tammy Sandoval related to the hit-and-run crash that killed three-year-old Khalil Robinson?"',
#   'answer': '"Tammy Sandoval was charged with six felonies related to the hit-and-run crash that killed three-year-old Khalil Robinson and left his mother Tia Robinson and twin sister Khloe in critical condition."'},
#  {'category': 'outbreak',
#   'fact': 'The Hopkins County Department of Health confirmed on July 11, 2025, that El Tapatio Mexican Cantina was the source of the Giardia outbreak, citing improper food storage temperatures during an inspection.\n',
#   'question': '"What was identified as the source of the Giardia outbreak confirmed by the Hopkins County Department of Health on July 11, 2025?"',
#   'answer': '"The source of the Giardia outbreak confirmed by the Hopkins County Department of Health on July 11, 2025, was El Tapatio Mexican Cantina, which was cited for improper food storage temperatures during an inspection."'},
#  {'category': 'unprecented',
#   'fact': 'Musante Beach in Leeds village, Northampton, will be closed on July 4 and throughout the holiday weekend in 2025 due to a lifeguard shortage, as announced by Northampton Aquatics Supervisor Jim Miller on Thursday.',
#   'question': '"Why will Musante Beach in Leeds village, Northampton, be closed on July 4 and throughout the holiday weekend in 2025?"',
#   'answer': '"Musante Beach in Leeds village, Northampton, will be closed on July 4 and throughout the holiday weekend in 2025 due to a lifeguard shortage, as announced by Northampton Aquatics Supervisor Jim Miller."'},
#  {'category': 'crash',
#   'fact': 'Westbound Interstate 76, closed between CO 2/Colorado Boulevard and CO 44/104th Avenue due to the crash, reopened to traffic at 8:14 a.m. on July 4, 2025.\n',
#   'question': '"What caused the closure of westbound Interstate 76 between CO 2/Colorado Boulevard and CO 44/104th Avenue?"',
#   'answer': '"Westbound Interstate 76 was closed between CO 2/Colorado Boulevard and CO 44/104th Avenue due to a crash."'},
#  {'category': 'discovery',
#   'fact': 'The Allen & Co. Sun Valley Conference took place earlier this week from July 10 to July 13, 2025, in Sun Valley, Idaho, gathering tech and media moguls including Apple CEO Tim Cook and Amazon founder Jeff Bezos.',
#   'question': '"Who were some of the notable attendees at the Allen & Co. Sun Valley Conference held in Sun Valley, Idaho?"',
#   'answer': '"Notable attendees at the Allen & Co. Sun Valley Conference included Apple CEO Tim Cook and Amazon founder Jeff Bezos."'},
#  {'category': 'strike',
#   'fact': 'The F-35 Lightning II, available in three variants for the Air Force, Navy, and Marines, is designed to function as a flying command center, capable of collecting and sharing vast amounts of intelligence in real time during missions.\n',
#   'question': '"What is the primary function of the F-35 Lightning II during missions?"',
#   'answer': '"The primary function of the F-35 Lightning II during missions is to act as a flying command center, capable of collecting and sharing vast amounts of intelligence in real time."'},
#  {'category': 'unprecented',
#   'fact': 'The Trump administration aims to achieve 1 million annual deportations as part of its immigration enforcement strategy, with plans to construct more border barriers and expand detention capacity.\n',
#   'question': '"What is the goal of the Trump administration regarding annual deportations as part of its immigration enforcement strategy?"',
#   'answer': '"The Trump administration aims to achieve 1 million annual deportations as part of its immigration enforcement strategy, with plans to construct more border barriers and expand detention capacity."'},
#  {'category': 'abrupt',
#   'fact': "A judge issued a temporary restraining order on August 3, 2025, to restore water service to the residents of Waldrop Place Condominiums after the homeowners association's actions led to a public health crisis.\n",
#   'question': '"What action did a judge take on August 3, 2025, regarding the water service for residents of Waldrop Place Condominiums?"',
#   'answer': '"A judge issued a temporary restraining order on August 3, 2025, to restore water service to the residents of Waldrop Place Condominiums after the homeowners association\'s actions led to a public health crisis."'},
#  {'category': 'earthquake',
#   'fact': "The tsunami warnings issued after the 8.8 magnitude earthquake in Russia's Far East extended to Hawaii, North and Central America, and Pacific islands as far south as New Zealand, with officials indicating that the potential tsunami danger may last for more than a day.\n",
#   'question': '"Which regions received tsunami warnings following the 8.8 magnitude earthquake in Russia\'s Far East?"',
#   'answer': '"Tsunami warnings were issued for Hawaii, North and Central America, and Pacific islands as far south as New Zealand following the 8.8 magnitude earthquake in Russia\'s Far East."'},
#  {'category': 'earthquake',
#   'fact': "More than 900,000 people were asked to evacuate along Japan's eastern seaboard following the earthquake, as authorities recorded tsunami waves up to 40 cm in 16 locations off the coast of Hokkaido.\n",
#   'question': '"What prompted the evacuation of more than 900,000 people along Japan\'s eastern seaboard?"',
#   'answer': '"The evacuation of more than 900,000 people along Japan\'s eastern seaboard was prompted by an earthquake, as authorities recorded tsunami waves up to 40 cm in 16 locations off the coast of Hokkaido."'},
#  {'category': 'crash',
#   'fact': 'A Cessna 208B aircraft crashed off the end of a runway at Cross Keys Airport in Williamstown, New Jersey, on July 3, 2025, with 15 people aboard, resulting in multiple casualties and injuries ranging from minor to critical.',
#   'question': '"What was the outcome of the Cessna 208B aircraft crash at Cross Keys Airport in Williamstown, New Jersey, on July 3, 2025?"',
#   'answer': '"The Cessna 208B aircraft crashed off the end of a runway at Cross Keys Airport in Williamstown, New Jersey, resulting in multiple casualties and injuries ranging from minor to critical, with 15 people aboard."'},
#  {'category': 'emergency',
#   'fact': 'Cameron Birdsong, a 25-year-old from Live Oak, was recovered from the Sacramento River after jumping from the Knights Landing Bridge on July 2, 2025, according to the Sutter County Sheriff’s Office.',
#   'question': '"What was the age and location of Cameron Birdsong when he was recovered from the Sacramento River after jumping from the Knights Landing Bridge?"',
#   'answer': '"Cameron Birdsong was 25 years old and from Live Oak when he was recovered from the Sacramento River after jumping from the Knights Landing Bridge."'},
#  {'category': 'discovery',
#   'fact': "On July 1, 2025, Paramount announced a $16 million settlement to resolve a lawsuit involving CBS' 60 Minutes, which includes an agreement to release transcripts of interviews with presidential candidates after airing.",
#   'question': '"What settlement amount did Paramount announce to resolve the lawsuit involving CBS\' 60 Minutes?"',
#   'answer': '"Paramount announced a $16 million settlement to resolve a lawsuit involving CBS\' 60 Minutes, which includes an agreement to release transcripts of interviews with presidential candidates after airing."'},
#  {'category': 'emergency',
#   'fact': 'The Federal Emergency Management Agency approved more than $1.8 million in aid for individual Tennesseans affected by severe storms in April 2025, with 206 individual assistance applications approved as of July 2, 2025.',
#   'question': '"How much aid did the Federal Emergency Management Agency approve for individual Tennesseans affected by severe storms in April 2025?"',
#   'answer': '"The Federal Emergency Management Agency approved more than $1.8 million in aid for individual Tennesseans affected by severe storms in April 2025, with 206 individual assistance applications approved."'},
#  {'category': 'strike',
#   'fact': 'Ukrzaliznytsia reported that reserve diesel locomotives have been deployed to transport passengers within the capital on the Sviatoshyn – Kyiv – Pasazhyrskyi section due to the disruptions caused by the attack.\n',
#   'question': '"Why were reserve diesel locomotives deployed by Ukrzaliznytsia to transport passengers within the capital?"',
#   'answer': '"Reserve diesel locomotives were deployed by Ukrzaliznytsia to transport passengers within the capital on the Sviatoshyn – Kyiv – Pasazhyrskyi section due to the disruptions caused by the attack."'},
#  {'category': 'strike',
#   'fact': 'The Russian Defense Ministry reported that Russian forces downed 120 drones overnight on July 6, 2025, with 30 intercepted over Bryansk Oblast and 29 over Kursk Oblast.\n',
#   'question': '"How many drones did Russian forces down overnight on July 6, 2025, and how many were intercepted over Bryansk Oblast and Kursk Oblast?"',
#   'answer': '"Russian forces downed 120 drones overnight on July 6, 2025, with 30 intercepted over Bryansk Oblast and 29 over Kursk Oblast."'},
#  {'category': 'strike',
#   'fact': 'Figma publicly shared its financials on July 3, 2025, inching closer to an IPO, with estimates suggesting it could raise up to $1.5 billion in the offering.',
#   'question': '"What financial milestone did Figma publicly share on July 3, 2025, as it inched closer to an IPO?"',
#   'answer': '"Figma publicly shared its financials on July 3, 2025, inching closer to an IPO, with estimates suggesting it could raise up to $1.5 billion in the offering."'},
#  {'category': 'outbreak',
#   'fact': 'In response to the outbreak, Royal Caribbean International implemented increased cleaning and disinfection procedures, collected stool specimens for testing, and isolated affected passengers and crew members.\n',
#   'question': '"What measures did Royal Caribbean International implement in response to the outbreak?"',
#   'answer': '"In response to the outbreak, Royal Caribbean International implemented increased cleaning and disinfection procedures, collected stool specimens for testing, and isolated affected passengers and crew members."'}]

# %%
def extract_rephrased_questions(response_text):
    question1 = response_text.split("1.")[1].split("2.")[0].strip()
    question2 = response_text.split("2.")[1].split("3.")[0].strip()
    question3 = response_text.split("3.")[1].split("4.")[0].strip()
    question4 = response_text.split("4.")[1].split("5.")[0].strip()
    question5 = response_text.split("5.")[1].split("6.")[0].strip()
    question6 = response_text.split("6.")[1].strip()
    return question1, question2, question3 , question4, question5, question6

# %%
import json
import os
import tqdm

OUTPUT_FILE = "extracted_QA/Rephrased_QA.jsonl"

done = set()
if os.path.exists(OUTPUT_FILE):
    with open(OUTPUT_FILE, "r", encoding="utf-8") as f:
        for line in f:
            try:
                obj = json.loads(line)
                done.add(obj["question"])
            except:
                continue

for example in tqdm.tqdm(data):
    if example["question"] in done:
        continue 

    prompt = prompt_for_question_rephrasing(example['question'])

    for attempt in range(2):
        try:
            response = client.responses.create(
                model="gpt-4o-mini",
                instructions="You are a helpful assistant",
                input=prompt,
                max_output_tokens=500,
                temperature=0.9
            )

            response = response.output_text.split("```")[1].replace("```", "").strip()
            q1, q2, q3, q4, q5, q6 = extract_rephrased_questions(response)

            example['rephrased_1'] = q1
            example['rephrased_2'] = q2
            example['rephrased_3'] = q3
            example['rephrased_4'] = q4
            example['rephrased_5'] = q5
            example['rephrased_6'] = q6

            with open(OUTPUT_FILE, "a", encoding="utf-8") as f:
                f.write(json.dumps(example, ensure_ascii=False) + "\n")

            break 

        except Exception as e:
            if attempt == 0:
                print(f"First attempt failed for '{example['question']}', retrying...")
            else:
                print(f"Second attempt failed for '{example['question']}', moving on...")
# Out:
#  86%|████████▌ | 2828/3300 [00:24<00:06, 77.13it/s]
# First attempt failed for '"What was the maximum sustained wind speed of Tropical Storm Chantal when it made landfall along the Carolina coast?"', retrying...
#  86%|████████▋ | 2851/3300 [00:30<00:07, 56.44it/s]
# Second attempt failed for '"What was the maximum sustained wind speed of Tropical Storm Chantal when it made landfall along the Carolina coast?"', moving on...
#  95%|█████████▌| 3142/3300 [01:09<00:18,  8.65it/s]
# First attempt failed for '"What did the 2019 Conservative government announce for chess players, and what key issues did it fail to address?"', retrying...
# 100%|██████████| 3300/3300 [01:21<00:00, 40.56it/s]
